# %%
# %% [markdown]
# ### 1. Import Libraries

# %%
import sys
import os
sys.path.append('../src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# %%
mport yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
import yfinance as yf
yf.set_tz_cache_location(None)

# %%
data = yf.download(
    ["TSLA", "BND", "SPY"],
    start="2015-01-01",
    end="2026-01-15",
    auto_adjust=True
)

# %%
import yfinance as yf

tsla = yf.download("TSLA", start="2015-01-01", end="2026-01-15", auto_adjust=True)
bnd  = yf.download("BND",  start="2015-01-01", end="2026-01-15", auto_adjust=True)
spy  = yf.download("SPY",  start="2015-01-01", end="2026-01-15", auto_adjust=True)

# %%
tsla.shape, bnd.shape, spy.shape

# %%
tsla.index.min(), tsla.index.max()

# %%
tsla.head()
bnd.head()
spy.head()
